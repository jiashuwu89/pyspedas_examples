# %% [markdown]
# # ELFIN EPD data loading example
# This notebook demonstrates how to load elfin state data, l1 and l2 epd data. And how to generate enegy and picth angle spectrogram with l2 data.

# %%
import pyspedas
from pytplot import tplot, tplot_options

# %% [markdown]
# ### 1. load elfin state tplot variables:

# %%
state_var = pyspedas.elfin.state(trange=['2022-01-14/06:28', '2022-01-14/06:35'], probe='a', no_update=True)
print(state_var)
# Out:
# 05-Oct-23 20:04:25: Searching for local files...
# 05-Oct-23 20:04:26: No VAR_TYPE or PARAMETER_TYPE attributes defined for variable ela_sun, skipping
# 05-Oct-23 20:04:26: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:26: This version will eventually be removed.
# 05-Oct-23 20:04:26: Time clip was applied to: ela_pos_gei
# 05-Oct-23 20:04:26: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:26: This version will eventually be removed.
# 05-Oct-23 20:04:26: Time clip was applied to: ela_vel_gei
# 05-Oct-23 20:04:26: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:26: This version will eventually be removed.
# 05-Oct-23 20:04:26: Time clip was applied to: ela_att_gei
# 05-Oct-23 20:04:26: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:26: This version will eventually be removed.
# 05-Oct-23 20:04:26: Time clip was applied to: ela_att_solution_date
# 05-Oct-23 20:04:26: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:26: This version will eventually be removed.
# 05-Oct-23 20:04:26: Time clip was applied to: ela_att_flag
# 05-Oct-23 20:04:26: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:26: This version will eventually be removed.
# 05-Oct-23 20:04:26: Time clip was applied to: ela_att_spinper
# 05-Oct-23 20:04:26: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:26: This version will eventually be removed.
# 05-Oct-23 20:04:26: Time clip was applied to: ela_spin_orbnorm_angle
# 05-Oct-23 20:04:26: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:26: This version will eventually be removed.
# 05-Oct-23 20:04:26: Time clip was applied to: ela_spin_sun_angle
# ['ela_pos_gei', 'ela_vel_gei', 'ela_att_gei', 'ela_att_solution_date', 'ela_att_flag', 'ela_att_spinper', 'ela_spin_orbnorm_angle', 'ela_spin_sun_angle']

# %% [markdown]
# plot position and attitude data

# %%
tplot(['ela_pos_gei', 'ela_att_gei'])

# %% [markdown]
# ### 2. load epd l1 tplot variables:
# l1 data can be loaded as type_='raw/cps/nflux/eflux'

# %%
# load raw data
epd_l1_raw = pyspedas.elfin.epd(
    trange=['2022-08-03/08:30:00','2022-08-03/09:00:00'], 
    probe='a', 
    level='l1', 
    type_='cps', 
    no_update=True)
print(epd_l1_raw)
# Out:
# 05-Oct-23 20:04:27: ELFIN EPD: START LOADING.
# 05-Oct-23 20:04:27: Searching for local files...
# 05-Oct-23 20:04:27: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:27: This version will eventually be removed.
# 05-Oct-23 20:04:27: Time clip was applied to: ela_pef
# 05-Oct-23 20:04:27: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:27: This version will eventually be removed.
# 05-Oct-23 20:04:27: Time clip was applied to: ela_pef_sectnum
# 05-Oct-23 20:04:27: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:27: This version will eventually be removed.
# 05-Oct-23 20:04:27: Time clip was applied to: ela_pef_nspinsinsum
# 05-Oct-23 20:04:27: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:27: This version will eventually be removed.
# 05-Oct-23 20:04:27: Time clip was applied to: ela_pef_nsectors
# 05-Oct-23 20:04:27: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:27: This version will eventually be removed.
# 05-Oct-23 20:04:28: Time clip was applied to: ela_pef_spinper
# 05-Oct-23 20:04:28: ELFIN EPD: LOADING END.
# 05-Oct-23 20:04:28: Using EPDE calibration data from 2018-09-17 00:00:00.000000
# 05-Oct-23 20:04:28: Deadtime correction applied with default deadtime; to not apply set deadtime_corr= 0. or a tiny value, e.g. 1.e-9
# ['ela_pef_cps', 'ela_pef_sectnum', 'ela_pef_nspinsinsum', 'ela_pef_nsectors', 'ela_pef_spinper']

# %%
# load cps data
epd_l1_cps = pyspedas.elfin.epd(
    trange=['2022-08-03/08:30:00','2022-08-03/09:00:00'], 
    probe='a', 
    level='l1', 
    type_='raw', 
    no_update=True)
print(epd_l1_cps)
# Out:
# 05-Oct-23 20:04:28: ELFIN EPD: START LOADING.
# 05-Oct-23 20:04:28: Searching for local files...
# 05-Oct-23 20:04:28: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:28: This version will eventually be removed.
# 05-Oct-23 20:04:28: Time clip was applied to: ela_pef
# 05-Oct-23 20:04:28: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:28: This version will eventually be removed.
# 05-Oct-23 20:04:28: Time clip was applied to: ela_pef_sectnum
# 05-Oct-23 20:04:28: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:28: This version will eventually be removed.
# 05-Oct-23 20:04:28: Time clip was applied to: ela_pef_nspinsinsum
# 05-Oct-23 20:04:28: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:28: This version will eventually be removed.
# 05-Oct-23 20:04:28: Time clip was applied to: ela_pef_nsectors
# 05-Oct-23 20:04:28: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:28: This version will eventually be removed.
# 05-Oct-23 20:04:28: Time clip was applied to: ela_pef_spinper
# 05-Oct-23 20:04:28: ELFIN EPD: LOADING END.
# 05-Oct-23 20:04:28: Using EPDE calibration data from 2018-09-17 00:00:00.000000
# 05-Oct-23 20:04:28: Deadtime correction applied with default deadtime; to not apply set deadtime_corr= 0. or a tiny value, e.g. 1.e-9
# ['ela_pef_raw', 'ela_pef_sectnum', 'ela_pef_nspinsinsum', 'ela_pef_nsectors', 'ela_pef_spinper']

# %%
# load nflux
epd_l1_nflux = pyspedas.elfin.epd(
    trange=['2022-08-03/08:30:00','2022-08-03/09:00:00'], 
    probe='a', 
    level='l1', 
    type_='nflux', 
    no_update=True)
print(epd_l1_nflux)
# Out:
# 05-Oct-23 20:04:28: ELFIN EPD: START LOADING.
# 05-Oct-23 20:04:28: Searching for local files...
# 05-Oct-23 20:04:28: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:28: This version will eventually be removed.
# 05-Oct-23 20:04:28: Time clip was applied to: ela_pef
# 05-Oct-23 20:04:28: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:28: This version will eventually be removed.
# 05-Oct-23 20:04:28: Time clip was applied to: ela_pef_sectnum
# 05-Oct-23 20:04:28: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:28: This version will eventually be removed.
# 05-Oct-23 20:04:28: Time clip was applied to: ela_pef_nspinsinsum
# 05-Oct-23 20:04:28: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:28: This version will eventually be removed.
# 05-Oct-23 20:04:28: Time clip was applied to: ela_pef_nsectors
# 05-Oct-23 20:04:28: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:28: This version will eventually be removed.
# 05-Oct-23 20:04:28: Time clip was applied to: ela_pef_spinper
# 05-Oct-23 20:04:28: ELFIN EPD: LOADING END.
# 05-Oct-23 20:04:28: Using EPDE calibration data from 2018-09-17 00:00:00.000000
# 05-Oct-23 20:04:28: Deadtime correction applied with default deadtime; to not apply set deadtime_corr= 0. or a tiny value, e.g. 1.e-9
# ['ela_pef_nflux', 'ela_pef_sectnum', 'ela_pef_nspinsinsum', 'ela_pef_nsectors', 'ela_pef_spinper']

# %%
# load eflux
epd_l1_eflux = pyspedas.elfin.epd(
    trange=['2022-08-03/08:30:00','2022-08-03/09:00:00'], 
    probe='a', 
    level='l1', 
    type_='eflux', 
    no_update=True)
print(epd_l1_eflux)
# Out:
# 05-Oct-23 20:04:28: ELFIN EPD: START LOADING.
# 05-Oct-23 20:04:28: Searching for local files...
# 05-Oct-23 20:04:28: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:28: This version will eventually be removed.
# 05-Oct-23 20:04:28: Time clip was applied to: ela_pef
# 05-Oct-23 20:04:28: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:28: This version will eventually be removed.
# 05-Oct-23 20:04:28: Time clip was applied to: ela_pef_sectnum
# 05-Oct-23 20:04:28: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:28: This version will eventually be removed.
# 05-Oct-23 20:04:28: Time clip was applied to: ela_pef_nspinsinsum
# 05-Oct-23 20:04:28: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:28: This version will eventually be removed.
# 05-Oct-23 20:04:28: Time clip was applied to: ela_pef_nsectors
# 05-Oct-23 20:04:28: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 05-Oct-23 20:04:28: This version will eventually be removed.
# 05-Oct-23 20:04:28: Time clip was applied to: ela_pef_spinper
# 05-Oct-23 20:04:28: ELFIN EPD: LOADING END.
# 05-Oct-23 20:04:28: Using EPDE calibration data from 2018-09-17 00:00:00.000000
# 05-Oct-23 20:04:28: Deadtime correction applied with default deadtime; to not apply set deadtime_corr= 0. or a tiny value, e.g. 1.e-9
# ['ela_pef_eflux', 'ela_pef_sectnum', 'ela_pef_nspinsinsum', 'ela_pef_nsectors', 'ela_pef_spinper']

# %% [markdown]
# plot epd l1 raw, cps, nflux and eflux together

# %%
tplot_options('wsize', [1600,500])
tplot(['ela_pef_raw', 'ela_pef_cps', 'ela_pef_nflux', 'ela_pef_eflux'])

# %% [markdown]
# ### 3. load epd l2 tplot variables:
# l2 spectrogram can be loaded in 'nflux/eflux' and 'halfspin/fullspin'
# Example of tplot variable names:
# - elx_pef_hs/fs_nflux/eflux_omni
# - elx_pef_hs/fs_nflux/eflux_para
# - elx_pef_hs/fs_nflux/eflux_anti
# - elx_pef_hs/fs_nflux/eflux_perp

# %%
# load l2 half spin nflux data
epd_l2_hs_nflux = pyspedas.elfin.epd(
    trange=['2022-08-28/15:54','2022-08-28/16:15'], 
    probe='a',
    level='l2', 
    type_='nflux', 
    fullspin=False,
    no_update=True)
print(epd_l2_hs_nflux)
# Out:
# 06-Oct-23 15:17:10: ELFIN EPD: START LOADING.
# 06-Oct-23 15:17:11: Searching for local files...
# 06-Oct-23 15:17:11: Unable to get ydata for variable ela_pef_Tspin
# 06-Oct-23 15:17:11: Conflicting size for at least one dimension for variable ela_pef_hs_epa_spec
# 06-Oct-23 15:17:11: Could not create coordinate v_dim for variable ela_pef_hs_epa_spec
# 06-Oct-23 15:17:11: Conflicting size for at least one dimension for variable ela_pef_fs_epa_spec
# 06-Oct-23 15:17:11: Could not create coordinate v_dim for variable ela_pef_fs_epa_spec
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_Et_nflux
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_Et_eflux
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_Et_dfovf
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_pa
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_spinphase
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_sectnum
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_hs_Epat_nflux
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_hs_Epat_eflux
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_hs_Epat_dfovf
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_hs_LCdeg
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_hs_antiLCdeg
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_hs_epa_spec
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_fs_Epat_nflux
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_fs_Epat_eflux
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_fs_Epat_dfovf
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_fs_LCdeg
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_fs_antiLCdeg
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_fs_epa_spec
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_nspinsinsum
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_nsectors
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_sect2add
# 06-Oct-23 15:17:11: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:11: This version will eventually be removed.
# 06-Oct-23 15:17:11: Time clip was applied to: ela_pef_spinph2add
# 06-Oct-23 15:17:11: ELFIN EPD: LOADING END.
# 06-Oct-23 15:17:11: ELFIN EPD L2: START PROCESSING.
# 06-Oct-23 15:17:11: ELFIN EPD L2: START ENERGY SPECTOGRAM.
# 06-Oct-23 15:17:11: ELFIN EPD L2: START PITCH ANGLE SPECTOGRAM.
# 06-Oct-23 15:17:11: Energy channel [(0, 2), (3, 5), (6, 8), (9, 15)] are used for epd l2 pitch angle spectra.
# ['ela_pef_hs_nflux_omni', 'ela_pef_hs_nflux_para', 'ela_pef_hs_nflux_anti', 'ela_pef_hs_nflux_perp', 'ela_pef_hs_nflux_ch0', 'ela_pef_hs_nflux_ch1', 'ela_pef_hs_nflux_ch2', 'ela_pef_hs_nflux_ch3']

# %%
# load l2 nflux full spin data
epd_l2_fs_nflux = pyspedas.elfin.epd(
    trange=['2022-08-28/15:54','2022-08-28/16:15'], 
    probe='a', 
    level='l2', 
    type_='nflux', 
    fullspin=True,
    no_update=True)
print(epd_l2_fs_nflux)
# Out:
# 06-Oct-23 15:17:30: ELFIN EPD: START LOADING.
# 06-Oct-23 15:17:30: Searching for local files...
# 06-Oct-23 15:17:30: Unable to get ydata for variable ela_pef_Tspin
# 06-Oct-23 15:17:30: Conflicting size for at least one dimension for variable ela_pef_hs_epa_spec
# 06-Oct-23 15:17:30: Could not create coordinate v_dim for variable ela_pef_hs_epa_spec
# 06-Oct-23 15:17:30: Conflicting size for at least one dimension for variable ela_pef_fs_epa_spec
# 06-Oct-23 15:17:30: Could not create coordinate v_dim for variable ela_pef_fs_epa_spec
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_Et_nflux
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_Et_eflux
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_Et_dfovf
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_pa
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_spinphase
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_sectnum
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_hs_Epat_nflux
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_hs_Epat_eflux
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_hs_Epat_dfovf
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_hs_LCdeg
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_hs_antiLCdeg
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_hs_epa_spec
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_fs_Epat_nflux
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_fs_Epat_eflux
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_fs_Epat_dfovf
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_fs_LCdeg
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_fs_antiLCdeg
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_fs_epa_spec
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_nspinsinsum
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_nsectors
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_sect2add
# 06-Oct-23 15:17:30: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:17:30: This version will eventually be removed.
# 06-Oct-23 15:17:30: Time clip was applied to: ela_pef_spinph2add
# 06-Oct-23 15:17:30: ELFIN EPD: LOADING END.
# 06-Oct-23 15:17:30: ELFIN EPD L2: START PROCESSING.
# 06-Oct-23 15:17:30: ELFIN EPD L2: START ENERGY SPECTOGRAM.
# 06-Oct-23 15:17:30: ELFIN EPD L2: START PITCH ANGLE SPECTOGRAM.
# 06-Oct-23 15:17:30: Energy channel [(0, 2), (3, 5), (6, 8), (9, 15)] are used for epd l2 pitch angle spectra.
# ['ela_pef_fs_nflux_omni', 'ela_pef_fs_nflux_para', 'ela_pef_fs_nflux_anti', 'ela_pef_fs_nflux_perp', 'ela_pef_fs_nflux_ch0', 'ela_pef_fs_nflux_ch1', 'ela_pef_fs_nflux_ch2', 'ela_pef_fs_nflux_ch3']

# %%
# load l2 half spin eflux data
epd_l2_hs_nflux = pyspedas.elfin.epd(
    trange=['2022-08-28/15:54','2022-08-28/16:15'], 
    probe='a', 
    level='l2', 
    type_='eflux', 
    fullspin=False,
    no_update=True)
print(epd_l2_hs_nflux)
# Out:
# 06-Oct-23 15:18:00: ELFIN EPD: START LOADING.
# 06-Oct-23 15:18:00: Searching for local files...
# 06-Oct-23 15:18:00: Unable to get ydata for variable ela_pef_Tspin
# 06-Oct-23 15:18:00: Conflicting size for at least one dimension for variable ela_pef_hs_epa_spec
# 06-Oct-23 15:18:00: Could not create coordinate v_dim for variable ela_pef_hs_epa_spec
# 06-Oct-23 15:18:00: Conflicting size for at least one dimension for variable ela_pef_fs_epa_spec
# 06-Oct-23 15:18:00: Could not create coordinate v_dim for variable ela_pef_fs_epa_spec
# 06-Oct-23 15:18:00: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:00: This version will eventually be removed.
# 06-Oct-23 15:18:00: Time clip was applied to: ela_pef_Et_nflux
# 06-Oct-23 15:18:00: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:00: This version will eventually be removed.
# 06-Oct-23 15:18:00: Time clip was applied to: ela_pef_Et_eflux
# 06-Oct-23 15:18:00: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:00: This version will eventually be removed.
# 06-Oct-23 15:18:00: Time clip was applied to: ela_pef_Et_dfovf
# 06-Oct-23 15:18:00: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:00: This version will eventually be removed.
# 06-Oct-23 15:18:00: Time clip was applied to: ela_pef_pa
# 06-Oct-23 15:18:00: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:00: This version will eventually be removed.
# 06-Oct-23 15:18:00: Time clip was applied to: ela_pef_spinphase
# 06-Oct-23 15:18:00: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:00: This version will eventually be removed.
# 06-Oct-23 15:18:00: Time clip was applied to: ela_pef_sectnum
# 06-Oct-23 15:18:00: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:00: This version will eventually be removed.
# 06-Oct-23 15:18:00: Time clip was applied to: ela_pef_hs_Epat_nflux
# 06-Oct-23 15:18:00: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:00: This version will eventually be removed.
# 06-Oct-23 15:18:00: Time clip was applied to: ela_pef_hs_Epat_eflux
# 06-Oct-23 15:18:00: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:00: This version will eventually be removed.
# 06-Oct-23 15:18:00: Time clip was applied to: ela_pef_hs_Epat_dfovf
# 06-Oct-23 15:18:00: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:00: This version will eventually be removed.
# 06-Oct-23 15:18:00: Time clip was applied to: ela_pef_hs_LCdeg
# 06-Oct-23 15:18:00: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:00: This version will eventually be removed.
# 06-Oct-23 15:18:00: Time clip was applied to: ela_pef_hs_antiLCdeg
# 06-Oct-23 15:18:00: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:00: This version will eventually be removed.
# 06-Oct-23 15:18:00: Time clip was applied to: ela_pef_hs_epa_spec
# 06-Oct-23 15:18:00: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:00: This version will eventually be removed.
# 06-Oct-23 15:18:01: Time clip was applied to: ela_pef_fs_Epat_nflux
# 06-Oct-23 15:18:01: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:01: This version will eventually be removed.
# 06-Oct-23 15:18:01: Time clip was applied to: ela_pef_fs_Epat_eflux
# 06-Oct-23 15:18:01: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:01: This version will eventually be removed.
# 06-Oct-23 15:18:01: Time clip was applied to: ela_pef_fs_Epat_dfovf
# 06-Oct-23 15:18:01: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:01: This version will eventually be removed.
# 06-Oct-23 15:18:01: Time clip was applied to: ela_pef_fs_LCdeg
# 06-Oct-23 15:18:01: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:01: This version will eventually be removed.
# 06-Oct-23 15:18:01: Time clip was applied to: ela_pef_fs_antiLCdeg
# 06-Oct-23 15:18:01: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:01: This version will eventually be removed.
# 06-Oct-23 15:18:01: Time clip was applied to: ela_pef_fs_epa_spec
# 06-Oct-23 15:18:01: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:01: This version will eventually be removed.
# 06-Oct-23 15:18:01: Time clip was applied to: ela_pef_nspinsinsum
# 06-Oct-23 15:18:01: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:01: This version will eventually be removed.
# 06-Oct-23 15:18:01: Time clip was applied to: ela_pef_nsectors
# 06-Oct-23 15:18:01: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:01: This version will eventually be removed.
# 06-Oct-23 15:18:01: Time clip was applied to: ela_pef_sect2add
# 06-Oct-23 15:18:01: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:01: This version will eventually be removed.
# 06-Oct-23 15:18:01: Time clip was applied to: ela_pef_spinph2add
# 06-Oct-23 15:18:01: ELFIN EPD: LOADING END.
# 06-Oct-23 15:18:01: ELFIN EPD L2: START PROCESSING.
# 06-Oct-23 15:18:01: ELFIN EPD L2: START ENERGY SPECTOGRAM.
# 06-Oct-23 15:18:01: ELFIN EPD L2: START PITCH ANGLE SPECTOGRAM.
# 06-Oct-23 15:18:01: Energy channel [(0, 2), (3, 5), (6, 8), (9, 15)] are used for epd l2 pitch angle spectra.
# ['ela_pef_hs_eflux_omni', 'ela_pef_hs_eflux_para', 'ela_pef_hs_eflux_anti', 'ela_pef_hs_eflux_perp', 'ela_pef_hs_eflux_ch0', 'ela_pef_hs_eflux_ch1', 'ela_pef_hs_eflux_ch2', 'ela_pef_hs_eflux_ch3']

# %%
# load l2 full spin eflux data
epd_l2_hs_nflux = pyspedas.elfin.epd(
    trange=['2022-08-28/15:54','2022-08-28/16:15'], 
    probe='a', 
    level='l2', 
    type_='eflux', 
    fullspin=True,
    no_update=True)
print(epd_l2_hs_nflux)
# Out:
# 06-Oct-23 15:18:54: ELFIN EPD: START LOADING.
# 06-Oct-23 15:18:54: Searching for local files...
# 06-Oct-23 15:18:54: Unable to get ydata for variable ela_pef_Tspin
# 06-Oct-23 15:18:55: Conflicting size for at least one dimension for variable ela_pef_hs_epa_spec
# 06-Oct-23 15:18:55: Could not create coordinate v_dim for variable ela_pef_hs_epa_spec
# 06-Oct-23 15:18:55: Conflicting size for at least one dimension for variable ela_pef_fs_epa_spec
# 06-Oct-23 15:18:55: Could not create coordinate v_dim for variable ela_pef_fs_epa_spec
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_Et_nflux
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_Et_eflux
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_Et_dfovf
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_pa
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_spinphase
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_sectnum
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_hs_Epat_nflux
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_hs_Epat_eflux
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_hs_Epat_dfovf
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_hs_LCdeg
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_hs_antiLCdeg
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_hs_epa_spec
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_fs_Epat_nflux
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_fs_Epat_eflux
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_fs_Epat_dfovf
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_fs_LCdeg
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_fs_antiLCdeg
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_fs_epa_spec
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_nspinsinsum
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_nsectors
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_sect2add
# 06-Oct-23 15:18:55: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 06-Oct-23 15:18:55: This version will eventually be removed.
# 06-Oct-23 15:18:55: Time clip was applied to: ela_pef_spinph2add
# 06-Oct-23 15:18:55: ELFIN EPD: LOADING END.
# 06-Oct-23 15:18:55: ELFIN EPD L2: START PROCESSING.
# 06-Oct-23 15:18:55: ELFIN EPD L2: START ENERGY SPECTOGRAM.
# 06-Oct-23 15:18:55: ELFIN EPD L2: START PITCH ANGLE SPECTOGRAM.
# 06-Oct-23 15:18:55: Energy channel [(0, 2), (3, 5), (6, 8), (9, 15)] are used for epd l2 pitch angle spectra.
# ['ela_pef_fs_eflux_omni', 'ela_pef_fs_eflux_para', 'ela_pef_fs_eflux_anti', 'ela_pef_fs_eflux_perp', 'ela_pef_fs_eflux_ch0', 'ela_pef_fs_eflux_ch1', 'ela_pef_fs_eflux_ch2', 'ela_pef_fs_eflux_ch3']

# %%
# plot energy spectrogram
tplot(['ela_pef_hs_nflux_omni', 'ela_pef_hs_eflux_para', 'ela_pef_hs_eflux_anti','ela_pef_hs_eflux_perp'])

# %%
# plot pitch angle spectrogram
tplot(['ela_pef_hs_nflux_ch0', 'ela_pef_hs_nflux_ch1', 'ela_pef_hs_nflux_ch2', 'ela_pef_hs_nflux_ch3'])
