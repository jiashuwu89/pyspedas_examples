# %% [markdown]
# # ELFIN EPD data loading example
# This notebook demonstrates how to load elfin state data, l1 and l2 epd data. And how to generate enegy and picth angle spectrogram with l2 data.

# %%
# %pip install --force-reinstall --no-cache-dir git+https://github.com/spedas/pyspedas.git@elfin
# Out:
# Collecting git+https://github.com/spedas/pyspedas.git@elfin
#   Cloning https://github.com/spedas/pyspedas.git (to revision elfin) to /private/var/folders/j5/kyr5s7ss0mqdt97dsy_q8zs00000gn/T/pip-req-build-0o8j9_3n
#   Running command git clone -q https://github.com/spedas/pyspedas.git /private/var/folders/j5/kyr5s7ss0mqdt97dsy_q8zs00000gn/T/pip-req-build-0o8j9_3n
#   Running command git checkout -b elfin --track origin/elfin
#   Switched to a new branch 'elfin'
#   branch 'elfin' set up to track 'origin/elfin'.
#   Resolved https://github.com/spedas/pyspedas.git to commit 1e5616e62e3c3eb228ccfc65615c5808ee395dc0
# Collecting numpy>=1.19.5
#   Downloading numpy-1.26.0-cp39-cp39-macosx_10_9_x86_64.whl (20.6 MB)
#      |████████████████████████████████| 20.6 MB 1.5 MB/s eta 0:00:01
# Collecting requests
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 30.0 MB/s eta 0:00:01
# Collecting geopack>=1.0.10
#   Downloading geopack-1.0.10-py3-none-any.whl (114 kB)
#      |████████████████████████████████| 114 kB 37.3 MB/s eta 0:00:01
# Collecting cdflib<1.0.0
#   Downloading cdflib-0.4.9-py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 25.4 MB/s eta 0:00:01
# Collecting cdasws>=1.7.24
#   Downloading cdasws-1.7.43.tar.gz (21 kB)
# Collecting netCDF4>=1.6.2
#   Downloading netCDF4-1.6.4-cp39-cp39-macosx_10_9_x86_64.whl (6.7 MB)
#      |████████████████████████████████| 6.7 MB 79.2 MB/s eta 0:00:01
# Collecting pywavelets
#   Downloading PyWavelets-1.4.1-cp39-cp39-macosx_10_13_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 53.4 MB/s eta 0:00:01
# Collecting astropy
#   Downloading astropy-5.3.4-cp39-cp39-macosx_10_9_x86_64.whl (7.1 MB)
#      |████████████████████████████████| 7.1 MB 26.0 MB/s eta 0:00:01
# Collecting hapiclient>=0.2.2
#   Downloading hapiclient-0.2.5.tar.gz (31 kB)
# Collecting pytplot-mpl-temp>=2.1.47
#   Downloading pytplot_mpl_temp-2.1.51-py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 59.0 MB/s eta 0:00:01
# Collecting viresclient
#   Downloading viresclient-0.11.3-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 50.3 MB/s eta 0:00:01
# Collecting python-dateutil>=2.8.0
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      |████████████████████████████████| 247 kB 50.7 MB/s eta 0:00:01
# Collecting scipy
#   Downloading scipy-1.11.3-cp39-cp39-macosx_10_9_x86_64.whl (37.3 MB)
#      |████████████████████████████████| 37.3 MB 26.9 MB/s eta 0:00:01
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 15.6 MB/s eta 0:00:01
# Collecting urllib3
#   Downloading urllib3-2.0.6-py3-none-any.whl (123 kB)
#      |████████████████████████████████| 123 kB 59.3 MB/s eta 0:00:01
# Collecting joblib
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#      |████████████████████████████████| 302 kB 40.4 MB/s eta 0:00:01
# Collecting pandas>=0.23
#   Downloading pandas-2.1.1-cp39-cp39-macosx_10_9_x86_64.whl (11.8 MB)
#      |████████████████████████████████| 11.8 MB 50.5 MB/s eta 0:00:01 | 4.4 MB 50.5 MB/s eta 0:00:01
# Collecting six
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting certifi
#   Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#      |████████████████████████████████| 158 kB 58.0 MB/s eta 0:00:01
# Collecting cftime
#   Downloading cftime-1.6.2-cp39-cp39-macosx_10_9_x86_64.whl (260 kB)
#      |████████████████████████████████| 260 kB 62.1 MB/s eta 0:00:01
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      |████████████████████████████████| 341 kB 55.7 MB/s eta 0:00:01
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#      |████████████████████████████████| 502 kB 55.0 MB/s eta 0:00:01
# Collecting matplotlib>=3.4
#   Downloading matplotlib-3.8.0-cp39-cp39-macosx_10_12_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 48.0 MB/s eta 0:00:01
# Collecting bokeh<3.0,>=1.1
#   Downloading bokeh-2.4.3-py3-none-any.whl (18.5 MB)
#      |████████████████████████████████| 18.5 MB 37.3 MB/s eta 0:00:01
# Collecting xarray
#   Downloading xarray-2023.9.0-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 78.4 MB/s eta 0:00:01
# Collecting pillow>=7.1.0
#   Downloading Pillow-10.0.1-cp39-cp39-macosx_10_10_x86_64.whl (3.7 MB)
#      |████████████████████████████████| 3.7 MB 83.7 MB/s eta 0:00:01
# Collecting Jinja2>=2.9
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 95.0 MB/s eta 0:00:01
# Collecting typing-extensions>=3.10.0
#   Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Collecting packaging>=16.8
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 32.7 MB/s eta 0:00:01
# Collecting PyYAML>=3.10
#   Downloading PyYAML-6.0.1-cp39-cp39-macosx_10_9_x86_64.whl (197 kB)
#      |████████████████████████████████| 197 kB 29.1 MB/s eta 0:00:01
# Collecting tornado>=5.1
#   Downloading tornado-6.3.3-cp38-abi3-macosx_10_9_x86_64.whl (423 kB)
#      |████████████████████████████████| 423 kB 47.7 MB/s eta 0:00:01
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.3-cp39-cp39-macosx_10_9_x86_64.whl (13 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.43.1-cp39-cp39-macosx_10_9_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 40.4 MB/s eta 0:00:01
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.1.0-py3-none-any.whl (33 kB)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 57.6 MB/s eta 0:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.1.1-cp39-cp39-macosx_10_9_x86_64.whl (247 kB)
#      |████████████████████████████████| 247 kB 60.7 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.5-cp39-cp39-macosx_10_9_x86_64.whl (68 kB)
#      |████████████████████████████████| 68 kB 39.8 MB/s eta 0:00:01
# Collecting zipp>=3.1.0
#   Downloading zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 6.3 MB/s  eta 0:00:01
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.0-cp39-cp39-macosx_10_9_x86_64.whl (119 kB)
#      |████████████████████████████████| 119 kB 80.2 MB/s eta 0:00:01
# Collecting pyerfa>=2.0
#   Downloading pyerfa-2.0.0.3-cp39-cp39-macosx_10_9_x86_64.whl (342 kB)
#      |████████████████████████████████| 342 kB 43.0 MB/s eta 0:00:01
# Collecting tables>=3.4.4
#   Downloading tables-3.9.1-cp39-cp39-macosx_10_9_x86_64.whl (7.3 MB)
#      |████████████████████████████████| 7.3 MB 12.5 MB/s eta 0:00:01
# Collecting tqdm>=4.23.0
#   Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 62.5 MB/s eta 0:00:01
# Collecting blosc2>=2.2.8
#   Downloading blosc2-2.2.9-cp39-cp39-macosx_10_9_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 45.2 MB/s eta 0:00:01
# Collecting py-cpuinfo
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Collecting numexpr>=2.6.2
#   Downloading numexpr-2.8.7-cp39-cp39-macosx_10_9_x86_64.whl (102 kB)
#      |████████████████████████████████| 102 kB 49.6 MB/s eta 0:00:01
# Collecting ndindex>=1.4
#   Downloading ndindex-1.7-py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 18.6 MB/s eta 0:00:01
# Collecting msgpack
#   Downloading msgpack-1.0.7-cp39-cp39-macosx_10_9_x86_64.whl (234 kB)
#      |████████████████████████████████| 234 kB 41.4 MB/s eta 0:00:01
# Using legacy 'setup.py install' for pyspedas, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for cdasws, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for hapiclient, since package 'wheel' is not installed.
# Installing collected packages: six, zipp, tzdata, pytz, python-dateutil, py-cpuinfo, numpy, ndindex, msgpack, MarkupSafe, urllib3, typing-extensions, tornado, PyYAML, pyparsing, pyerfa, pillow, pandas, packaging, numexpr, kiwisolver, Jinja2, importlib-resources, idna, fonttools, cycler, contourpy, charset-normalizer, cftime, certifi, blosc2, xarray, tqdm, tables, scipy, requests, netCDF4, matplotlib, joblib, isodate, cdflib, bokeh, astropy, viresclient, pywavelets, pytplot-mpl-temp, hapiclient, geopack, cdasws, pyspedas
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.17.0
#     Uninstalling zipp-3.17.0:
#       Successfully uninstalled zipp-3.17.0
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2023.3
#     Uninstalling tzdata-2023.3:
#       Successfully uninstalled tzdata-2023.3
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2023.3.post1
#     Uninstalling pytz-2023.3.post1:
#       Successfully uninstalled pytz-2023.3.post1
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
#       Successfully uninstalled python-dateutil-2.8.2
#   Attempting uninstall: py-cpuinfo
#     Found existing installation: py-cpuinfo 9.0.0
#     Uninstalling py-cpuinfo-9.0.0:
#       Successfully uninstalled py-cpuinfo-9.0.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.0
#     Uninstalling numpy-1.26.0:
#       Successfully uninstalled numpy-1.26.0
#   Attempting uninstall: ndindex
#     Found existing installation: ndindex 1.7
#     Uninstalling ndindex-1.7:
#       Successfully uninstalled ndindex-1.7
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.0.7
#     Uninstalling msgpack-1.0.7:
#       Successfully uninstalled msgpack-1.0.7
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.1.3
#     Uninstalling MarkupSafe-2.1.3:
#       Successfully uninstalled MarkupSafe-2.1.3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.6
#     Uninstalling urllib3-2.0.6:
#       Successfully uninstalled urllib3-2.0.6
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.8.0
#     Uninstalling typing-extensions-4.8.0:
#       Successfully uninstalled typing-extensions-4.8.0
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.3.3
#     Uninstalling tornado-6.3.3:
#       Successfully uninstalled tornado-6.3.3
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: pyerfa
#     Found existing installation: pyerfa 2.0.0.3
#     Uninstalling pyerfa-2.0.0.3:
#       Successfully uninstalled pyerfa-2.0.0.3
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 10.0.1
#     Uninstalling Pillow-10.0.1:
#       Successfully uninstalled Pillow-10.0.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.1
#     Uninstalling pandas-2.1.1:
#       Successfully uninstalled pandas-2.1.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.2
#     Uninstalling packaging-23.2:
#       Successfully uninstalled packaging-23.2
#   Attempting uninstall: numexpr
#     Found existing installation: numexpr 2.8.7
#     Uninstalling numexpr-2.8.7:
#       Successfully uninstalled numexpr-2.8.7
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.4.5
#     Uninstalling kiwisolver-1.4.5:
#       Successfully uninstalled kiwisolver-1.4.5
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 3.1.2
#     Uninstalling Jinja2-3.1.2:
#       Successfully uninstalled Jinja2-3.1.2
#   Attempting uninstall: importlib-resources
#     Found existing installation: importlib-resources 6.1.0
#     Uninstalling importlib-resources-6.1.0:
#       Successfully uninstalled importlib-resources-6.1.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.43.1
#     Uninstalling fonttools-4.43.1:
#       Successfully uninstalled fonttools-4.43.1
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: contourpy
#     Found existing installation: contourpy 1.1.1
#     Uninstalling contourpy-1.1.1:
#       Successfully uninstalled contourpy-1.1.1
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.3.0
#     Uninstalling charset-normalizer-3.3.0:
#       Successfully uninstalled charset-normalizer-3.3.0
#   Attempting uninstall: cftime
#     Found existing installation: cftime 1.6.2
#     Uninstalling cftime-1.6.2:
#       Successfully uninstalled cftime-1.6.2
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.7.22
#     Uninstalling certifi-2023.7.22:
#       Successfully uninstalled certifi-2023.7.22
#   Attempting uninstall: blosc2
#     Found existing installation: blosc2 2.2.9
#     Uninstalling blosc2-2.2.9:
#       Successfully uninstalled blosc2-2.2.9
#   Attempting uninstall: xarray
#     Found existing installation: xarray 2023.9.0
#     Uninstalling xarray-2023.9.0:
#       Successfully uninstalled xarray-2023.9.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
#   Attempting uninstall: tables
#     Found existing installation: tables 3.9.1
#     Uninstalling tables-3.9.1:
#       Successfully uninstalled tables-3.9.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.3
#     Uninstalling scipy-1.11.3:
#       Successfully uninstalled scipy-1.11.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: netCDF4
#     Found existing installation: netCDF4 1.6.4
#     Uninstalling netCDF4-1.6.4:
#       Successfully uninstalled netCDF4-1.6.4
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.0
#     Uninstalling matplotlib-3.8.0:
#       Successfully uninstalled matplotlib-3.8.0
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.3.2
#     Uninstalling joblib-1.3.2:
#       Successfully uninstalled joblib-1.3.2
#   Attempting uninstall: isodate
#     Found existing installation: isodate 0.6.1
#     Uninstalling isodate-0.6.1:
#       Successfully uninstalled isodate-0.6.1
#   Attempting uninstall: cdflib
#     Found existing installation: cdflib 0.4.9
#     Uninstalling cdflib-0.4.9:
#       Successfully uninstalled cdflib-0.4.9
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 2.4.3
#     Uninstalling bokeh-2.4.3:
#       Successfully uninstalled bokeh-2.4.3
#   Attempting uninstall: astropy
#     Found existing installation: astropy 5.3.4
#     Uninstalling astropy-5.3.4:
#       Successfully uninstalled astropy-5.3.4
#   Attempting uninstall: viresclient
#     Found existing installation: viresclient 0.11.3
#     Uninstalling viresclient-0.11.3:
#       Successfully uninstalled viresclient-0.11.3
#   Attempting uninstall: pywavelets
#     Found existing installation: PyWavelets 1.4.1
#     Uninstalling PyWavelets-1.4.1:
#       Successfully uninstalled PyWavelets-1.4.1
#   Attempting uninstall: pytplot-mpl-temp
#     Found existing installation: pytplot-mpl-temp 2.1.51
#     Uninstalling pytplot-mpl-temp-2.1.51:
#       Successfully uninstalled pytplot-mpl-temp-2.1.51
#   Attempting uninstall: hapiclient
#     Found existing installation: hapiclient 0.2.5
#     Uninstalling hapiclient-0.2.5:
#       Successfully uninstalled hapiclient-0.2.5
#     Running setup.py install for hapiclient ... done
#   Attempting uninstall: geopack
#     Found existing installation: geopack 1.0.10
#     Uninstalling geopack-1.0.10:
#       Successfully uninstalled geopack-1.0.10
#   Attempting uninstall: cdasws
#     Found existing installation: cdasws 1.7.43
#     Uninstalling cdasws-1.7.43:
#       Successfully uninstalled cdasws-1.7.43
#     Running setup.py install for cdasws ... done
#   Attempting uninstall: pyspedas
#     Found existing installation: pyspedas 1.4.44
#     Uninstalling pyspedas-1.4.44:
#       Successfully uninstalled pyspedas-1.4.44
#     Running setup.py install for pyspedas ... done
# Successfully installed Jinja2-3.1.2 MarkupSafe-2.1.3 PyYAML-6.0.1 astropy-5.3.4 blosc2-2.2.9 bokeh-2.4.3 cdasws-1.7.43 cdflib-0.4.9 certifi-2023.7.22 cftime-1.6.2 charset-normalizer-3.3.0 contourpy-1.1.1 cycler-0.12.1 fonttools-4.43.1 geopack-1.0.10 hapiclient-0.2.5 idna-3.4 importlib-resources-6.1.0 isodate-0.6.1 joblib-1.3.2 kiwisolver-1.4.5 matplotlib-3.8.0 msgpack-1.0.7 ndindex-1.7 netCDF4-1.6.4 numexpr-2.8.7 numpy-1.26.0 packaging-23.2 pandas-2.1.1 pillow-10.0.1 py-cpuinfo-9.0.0 pyerfa-2.0.0.3 pyparsing-3.1.1 pyspedas-1.4.44 python-dateutil-2.8.2 pytplot-mpl-temp-2.1.51 pytz-2023.3.post1 pywavelets-1.4.1 requests-2.31.0 scipy-1.11.3 six-1.16.0 tables-3.9.1 tornado-6.3.3 tqdm-4.66.1 typing-extensions-4.8.0 tzdata-2023.3 urllib3-2.0.6 viresclient-0.11.3 xarray-2023.9.0 zipp-3.17.0
# WARNING: You are using pip version 21.2.3; however, version 23.2.1 is available.
# You should consider upgrading via the '/Users/jiashu/Documents/VScode/pyspedas_examples/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyspedas
from pytplot import tplot, store_data, options

# %%
trange = ['2021-07-14/11:55', '2021-07-14/12:05']
probe='a'

# %% [markdown]
# ### 1. load elfin state tplot variables:
# Eight variables will be loaded:
# - ela_pos_gei
# - ela_vel_gei
# - ela_att_gei
# - ela_att_solution_date
# - ela_att_flag
# - ela_att_spinper
# - ela_spin_orbnorm_angle
# - ela_spin_sun_angle

# %%
state_var = pyspedas.elfin.state(trange=trange, probe=probe)
# Out:
# 10-Oct-23 00:14:54: Downloading remote index: https://data.elfin.ucla.edu/ela/l1/state/defn/2021/
# 10-Oct-23 00:14:56: File is current: elfin_data/ela/l1/state/defn/2021/ela_l1_state_defn_20210714_v02.cdf
# 10-Oct-23 00:14:56: No VAR_TYPE or PARAMETER_TYPE attributes defined for variable ela_sun, skipping
# 10-Oct-23 00:14:56: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:14:56: This version will eventually be removed.
# 10-Oct-23 00:14:56: Time clip was applied to: ela_pos_gei
# 10-Oct-23 00:14:56: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:14:56: This version will eventually be removed.
# 10-Oct-23 00:14:56: Time clip was applied to: ela_vel_gei
# 10-Oct-23 00:14:56: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:14:56: This version will eventually be removed.
# 10-Oct-23 00:14:56: Time clip was applied to: ela_att_gei
# 10-Oct-23 00:14:56: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:14:56: This version will eventually be removed.
# 10-Oct-23 00:14:56: Time clip was applied to: ela_att_solution_date
# 10-Oct-23 00:14:56: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:14:56: This version will eventually be removed.
# 10-Oct-23 00:14:56: Time clip was applied to: ela_att_flag
# 10-Oct-23 00:14:56: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:14:56: This version will eventually be removed.
# 10-Oct-23 00:14:56: Time clip was applied to: ela_att_spinper
# 10-Oct-23 00:14:56: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:14:56: This version will eventually be removed.
# 10-Oct-23 00:14:56: Time clip was applied to: ela_spin_orbnorm_angle
# 10-Oct-23 00:14:56: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:14:56: This version will eventually be removed.
# 10-Oct-23 00:14:56: Time clip was applied to: ela_spin_sun_angle

# %% [markdown]
# plot position and attitude data

# %%
tplot(['ela_pos_gei', 'ela_att_gei'])

# %% [markdown]
# ### 2. load epd l1 tplot variables:
# l1 data can be loaded as 'raw/cps/nflux/eflux'. Five variables will be loaded:
# - ela_pef_raw/cps/nflux/eflux
# - ela_pef_sectnum
# - ela_pef_nspinsinsum
# - ela_pef_nsectors
# - ela_pef_spinper

# %%
# load raw data
epd_l1_raw = pyspedas.elfin.epd(
    trange=trange, 
    probe=probe, 
    level='l1', 
    type_='cps')
# Out:
# 10-Oct-23 00:15:00: ELFIN EPD: START LOADING.
# 10-Oct-23 00:15:00: Downloading remote index: https://data.elfin.ucla.edu/ela/l1/epd/fast/electron/2021/
# 10-Oct-23 00:15:01: File is current: elfin_data/ela/l1/epd/fast/electron/2021/ela_l1_epdef_20210714_v01.cdf
# 10-Oct-23 00:15:01: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:01: This version will eventually be removed.
# 10-Oct-23 00:15:01: Time clip was applied to: ela_pef
# 10-Oct-23 00:15:01: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:01: This version will eventually be removed.
# 10-Oct-23 00:15:01: Time clip was applied to: ela_pef_sectnum
# 10-Oct-23 00:15:01: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:01: This version will eventually be removed.
# 10-Oct-23 00:15:01: Time clip was applied to: ela_pef_nspinsinsum
# 10-Oct-23 00:15:01: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:01: This version will eventually be removed.
# 10-Oct-23 00:15:01: Time clip was applied to: ela_pef_nsectors
# 10-Oct-23 00:15:01: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:01: This version will eventually be removed.
# 10-Oct-23 00:15:01: Time clip was applied to: ela_pef_spinper
# 10-Oct-23 00:15:01: ELFIN EPD: LOADING END.
# 10-Oct-23 00:15:01: Using EPDE calibration data from 2018-09-17 00:00:00.000000
# 10-Oct-23 00:15:01: Deadtime correction applied with default deadtime; to not apply set deadtime_corr= 0. or a tiny value, e.g. 1.e-9

# %%
# load cps data
epd_l1_cps = pyspedas.elfin.epd(
    trange=trange, 
    probe=probe, 
    level='l1', 
    type_='raw')
# Out:
# 10-Oct-23 00:15:01: ELFIN EPD: START LOADING.
# 10-Oct-23 00:15:01: Downloading remote index: https://data.elfin.ucla.edu/ela/l1/epd/fast/electron/2021/
# 10-Oct-23 00:15:01: File is current: elfin_data/ela/l1/epd/fast/electron/2021/ela_l1_epdef_20210714_v01.cdf
# 10-Oct-23 00:15:02: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:02: This version will eventually be removed.
# 10-Oct-23 00:15:02: Time clip was applied to: ela_pef
# 10-Oct-23 00:15:02: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:02: This version will eventually be removed.
# 10-Oct-23 00:15:02: Time clip was applied to: ela_pef_sectnum
# 10-Oct-23 00:15:02: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:02: This version will eventually be removed.
# 10-Oct-23 00:15:02: Time clip was applied to: ela_pef_nspinsinsum
# 10-Oct-23 00:15:02: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:02: This version will eventually be removed.
# 10-Oct-23 00:15:02: Time clip was applied to: ela_pef_nsectors
# 10-Oct-23 00:15:02: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:02: This version will eventually be removed.
# 10-Oct-23 00:15:02: Time clip was applied to: ela_pef_spinper
# 10-Oct-23 00:15:02: ELFIN EPD: LOADING END.
# 10-Oct-23 00:15:02: Using EPDE calibration data from 2018-09-17 00:00:00.000000
# 10-Oct-23 00:15:02: Deadtime correction applied with default deadtime; to not apply set deadtime_corr= 0. or a tiny value, e.g. 1.e-9

# %%
# load nflux
epd_l1_nflux = pyspedas.elfin.epd(
    trange=trange, 
    probe=probe, 
    level='l1', 
    type_='nflux')
# Out:
# 10-Oct-23 00:15:02: ELFIN EPD: START LOADING.
# 10-Oct-23 00:15:02: Downloading remote index: https://data.elfin.ucla.edu/ela/l1/epd/fast/electron/2021/
# 10-Oct-23 00:15:02: File is current: elfin_data/ela/l1/epd/fast/electron/2021/ela_l1_epdef_20210714_v01.cdf
# 10-Oct-23 00:15:02: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:02: This version will eventually be removed.
# 10-Oct-23 00:15:02: Time clip was applied to: ela_pef
# 10-Oct-23 00:15:02: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:02: This version will eventually be removed.
# 10-Oct-23 00:15:02: Time clip was applied to: ela_pef_sectnum
# 10-Oct-23 00:15:02: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:02: This version will eventually be removed.
# 10-Oct-23 00:15:02: Time clip was applied to: ela_pef_nspinsinsum
# 10-Oct-23 00:15:02: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:02: This version will eventually be removed.
# 10-Oct-23 00:15:02: Time clip was applied to: ela_pef_nsectors
# 10-Oct-23 00:15:02: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:02: This version will eventually be removed.
# 10-Oct-23 00:15:02: Time clip was applied to: ela_pef_spinper
# 10-Oct-23 00:15:02: ELFIN EPD: LOADING END.
# 10-Oct-23 00:15:02: Using EPDE calibration data from 2018-09-17 00:00:00.000000
# 10-Oct-23 00:15:02: Deadtime correction applied with default deadtime; to not apply set deadtime_corr= 0. or a tiny value, e.g. 1.e-9

# %%
# load eflux
epd_l1_eflux = pyspedas.elfin.epd(
    trange=trange, 
    probe=probe, 
    level='l1', 
    type_='eflux')
# Out:
# 10-Oct-23 00:15:02: ELFIN EPD: START LOADING.
# 10-Oct-23 00:15:02: Downloading remote index: https://data.elfin.ucla.edu/ela/l1/epd/fast/electron/2021/
# 10-Oct-23 00:15:03: File is current: elfin_data/ela/l1/epd/fast/electron/2021/ela_l1_epdef_20210714_v01.cdf
# 10-Oct-23 00:15:03: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:03: This version will eventually be removed.
# 10-Oct-23 00:15:03: Time clip was applied to: ela_pef
# 10-Oct-23 00:15:03: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:03: This version will eventually be removed.
# 10-Oct-23 00:15:03: Time clip was applied to: ela_pef_sectnum
# 10-Oct-23 00:15:03: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:03: This version will eventually be removed.
# 10-Oct-23 00:15:03: Time clip was applied to: ela_pef_nspinsinsum
# 10-Oct-23 00:15:03: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:03: This version will eventually be removed.
# 10-Oct-23 00:15:03: Time clip was applied to: ela_pef_nsectors
# 10-Oct-23 00:15:03: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:03: This version will eventually be removed.
# 10-Oct-23 00:15:03: Time clip was applied to: ela_pef_spinper
# 10-Oct-23 00:15:03: ELFIN EPD: LOADING END.
# 10-Oct-23 00:15:03: Using EPDE calibration data from 2018-09-17 00:00:00.000000
# 10-Oct-23 00:15:03: Deadtime correction applied with default deadtime; to not apply set deadtime_corr= 0. or a tiny value, e.g. 1.e-9

# %% [markdown]
# plot epd l1 raw and eflux together

# %%
tplot(['ela_pef_raw', 'ela_pef_eflux'])

# %% [markdown]
# ### 3. load epd l2 tplot variables:
# L2 spectrogram can be loaded in 'nflux/eflux' and 'halfspin/fullspin'
# Energy spectrogram variable names:
# - elx_pef_hs/fs_nflux/eflux_omni
# - elx_pef_hs/fs_nflux/eflux_para
# - elx_pef_hs/fs_nflux/eflux_anti
# - elx_pef_hs/fs_nflux/eflux_perp
#
# Pitch angle spectrogram variable names:
# - elx_pef_hs/fs_nflux/eflux_ch0-3

# %% [markdown]
# #### 3.1 plot energy and pitch angle spectrogram

# %%
# load l2 half spin nflux data
epd_l2_hs_nflux = pyspedas.elfin.epd(
    trange=trange, 
    probe=probe,
    level='l2', 
    type_='nflux', 
    fullspin=False)
# Out:
# 10-Oct-23 00:15:04: ELFIN EPD: START LOADING.
# 10-Oct-23 00:15:04: Downloading remote index: https://data.elfin.ucla.edu/ela/l2/epd/fast/electron/2021/
# 10-Oct-23 00:15:04: File is current: elfin_data/ela/l2/epd/fast/electron/2021/ela_l2_epdef_20210714_v01.cdf
# 10-Oct-23 00:15:04: Unable to get ydata for variable ela_pef_Tspin
# 10-Oct-23 00:15:05: Conflicting size for at least one dimension for variable ela_pef_hs_epa_spec
# 10-Oct-23 00:15:05: Could not create coordinate v_dim for variable ela_pef_hs_epa_spec
# 10-Oct-23 00:15:05: Conflicting size for at least one dimension for variable ela_pef_fs_epa_spec
# 10-Oct-23 00:15:05: Could not create coordinate v_dim for variable ela_pef_fs_epa_spec
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_Et_nflux
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_Et_eflux
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_Et_dfovf
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_pa
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_spinphase
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_sectnum
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_hs_Epat_nflux
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_hs_Epat_eflux
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_hs_Epat_dfovf
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_hs_LCdeg
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_hs_antiLCdeg
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_hs_epa_spec
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_fs_Epat_nflux
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_fs_Epat_eflux
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_fs_Epat_dfovf
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_fs_LCdeg
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_fs_antiLCdeg
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_fs_epa_spec
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_nspinsinsum
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_nsectors
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_sect2add
# 10-Oct-23 00:15:05: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:05: This version will eventually be removed.
# 10-Oct-23 00:15:05: Time clip was applied to: ela_pef_spinph2add
# 10-Oct-23 00:15:05: ELFIN EPD: LOADING END.
# 10-Oct-23 00:15:05: ELFIN EPD L2: START PROCESSING.
# 10-Oct-23 00:15:05: ELFIN EPD L2: START ENERGY SPECTOGRAM.
# 10-Oct-23 00:15:05: ELFIN EPD L2: START PITCH ANGLE SPECTOGRAM.
# 10-Oct-23 00:15:05: Energy channel [(0, 2), (3, 5), (6, 8), (9, 15)] are used for epd l2 pitch angle spectra.

# %%
# load l2 nflux full spin data
epd_l2_fs_nflux = pyspedas.elfin.epd(
    trange=trange, 
    probe=probe, 
    level='l2', 
    type_='nflux', 
    fullspin=True)
# Out:
# 10-Oct-23 00:15:05: ELFIN EPD: START LOADING.
# 10-Oct-23 00:15:05: Downloading remote index: https://data.elfin.ucla.edu/ela/l2/epd/fast/electron/2021/
# 10-Oct-23 00:15:06: File is current: elfin_data/ela/l2/epd/fast/electron/2021/ela_l2_epdef_20210714_v01.cdf
# 10-Oct-23 00:15:06: Unable to get ydata for variable ela_pef_Tspin
# 10-Oct-23 00:15:06: Conflicting size for at least one dimension for variable ela_pef_hs_epa_spec
# 10-Oct-23 00:15:06: Could not create coordinate v_dim for variable ela_pef_hs_epa_spec
# 10-Oct-23 00:15:06: Conflicting size for at least one dimension for variable ela_pef_fs_epa_spec
# 10-Oct-23 00:15:06: Could not create coordinate v_dim for variable ela_pef_fs_epa_spec
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:06: Time clip was applied to: ela_pef_Et_nflux
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:06: Time clip was applied to: ela_pef_Et_eflux
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:06: Time clip was applied to: ela_pef_Et_dfovf
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:06: Time clip was applied to: ela_pef_pa
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:06: Time clip was applied to: ela_pef_spinphase
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:06: Time clip was applied to: ela_pef_sectnum
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:06: Time clip was applied to: ela_pef_hs_Epat_nflux
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:06: Time clip was applied to: ela_pef_hs_Epat_eflux
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:06: Time clip was applied to: ela_pef_hs_Epat_dfovf
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:06: Time clip was applied to: ela_pef_hs_LCdeg
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:06: Time clip was applied to: ela_pef_hs_antiLCdeg
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:06: Time clip was applied to: ela_pef_hs_epa_spec
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:06: Time clip was applied to: ela_pef_fs_Epat_nflux
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:06: Time clip was applied to: ela_pef_fs_Epat_eflux
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:06: Time clip was applied to: ela_pef_fs_Epat_dfovf
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:06: Time clip was applied to: ela_pef_fs_LCdeg
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:06: Time clip was applied to: ela_pef_fs_antiLCdeg
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:06: Time clip was applied to: ela_pef_fs_epa_spec
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:06: Time clip was applied to: ela_pef_nspinsinsum
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:06: Time clip was applied to: ela_pef_nsectors
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:06: Time clip was applied to: ela_pef_sect2add
# 10-Oct-23 00:15:06: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:06: This version will eventually be removed.
# 10-Oct-23 00:15:07: Time clip was applied to: ela_pef_spinph2add
# 10-Oct-23 00:15:07: ELFIN EPD: LOADING END.
# 10-Oct-23 00:15:07: ELFIN EPD L2: START PROCESSING.
# 10-Oct-23 00:15:07: ELFIN EPD L2: START ENERGY SPECTOGRAM.
# 10-Oct-23 00:15:07: ELFIN EPD L2: START PITCH ANGLE SPECTOGRAM.
# 10-Oct-23 00:15:07: Energy channel [(0, 2), (3, 5), (6, 8), (9, 15)] are used for epd l2 pitch angle spectra.

# %%
# load l2 half spin eflux data
epd_l2_hs_nflux = pyspedas.elfin.epd(
    trange=trange, 
    probe=probe, 
    level='l2', 
    type_='eflux', 
    fullspin=False)
# Out:
# 10-Oct-23 00:15:07: ELFIN EPD: START LOADING.
# 10-Oct-23 00:15:07: Downloading remote index: https://data.elfin.ucla.edu/ela/l2/epd/fast/electron/2021/
# 10-Oct-23 00:15:07: File is current: elfin_data/ela/l2/epd/fast/electron/2021/ela_l2_epdef_20210714_v01.cdf
# 10-Oct-23 00:15:07: Unable to get ydata for variable ela_pef_Tspin
# 10-Oct-23 00:15:07: Conflicting size for at least one dimension for variable ela_pef_hs_epa_spec
# 10-Oct-23 00:15:07: Could not create coordinate v_dim for variable ela_pef_hs_epa_spec
# 10-Oct-23 00:15:07: Conflicting size for at least one dimension for variable ela_pef_fs_epa_spec
# 10-Oct-23 00:15:07: Could not create coordinate v_dim for variable ela_pef_fs_epa_spec
# 10-Oct-23 00:15:07: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:07: This version will eventually be removed.
# 10-Oct-23 00:15:07: Time clip was applied to: ela_pef_Et_nflux
# 10-Oct-23 00:15:07: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:07: This version will eventually be removed.
# 10-Oct-23 00:15:07: Time clip was applied to: ela_pef_Et_eflux
# 10-Oct-23 00:15:07: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:07: This version will eventually be removed.
# 10-Oct-23 00:15:07: Time clip was applied to: ela_pef_Et_dfovf
# 10-Oct-23 00:15:07: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:07: This version will eventually be removed.
# 10-Oct-23 00:15:07: Time clip was applied to: ela_pef_pa
# 10-Oct-23 00:15:07: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:07: This version will eventually be removed.
# 10-Oct-23 00:15:07: Time clip was applied to: ela_pef_spinphase
# 10-Oct-23 00:15:07: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:07: This version will eventually be removed.
# 10-Oct-23 00:15:08: Time clip was applied to: ela_pef_sectnum
# 10-Oct-23 00:15:08: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:08: This version will eventually be removed.
# 10-Oct-23 00:15:08: Time clip was applied to: ela_pef_hs_Epat_nflux
# 10-Oct-23 00:15:08: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:08: This version will eventually be removed.
# 10-Oct-23 00:15:08: Time clip was applied to: ela_pef_hs_Epat_eflux
# 10-Oct-23 00:15:08: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:08: This version will eventually be removed.
# 10-Oct-23 00:15:08: Time clip was applied to: ela_pef_hs_Epat_dfovf
# 10-Oct-23 00:15:08: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:08: This version will eventually be removed.
# 10-Oct-23 00:15:08: Time clip was applied to: ela_pef_hs_LCdeg
# 10-Oct-23 00:15:08: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:08: This version will eventually be removed.
# 10-Oct-23 00:15:08: Time clip was applied to: ela_pef_hs_antiLCdeg
# 10-Oct-23 00:15:08: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:08: This version will eventually be removed.
# 10-Oct-23 00:15:08: Time clip was applied to: ela_pef_hs_epa_spec
# 10-Oct-23 00:15:08: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:08: This version will eventually be removed.
# 10-Oct-23 00:15:08: Time clip was applied to: ela_pef_fs_Epat_nflux
# 10-Oct-23 00:15:08: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:08: This version will eventually be removed.
# 10-Oct-23 00:15:08: Time clip was applied to: ela_pef_fs_Epat_eflux
# 10-Oct-23 00:15:08: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:08: This version will eventually be removed.
# 10-Oct-23 00:15:08: Time clip was applied to: ela_pef_fs_Epat_dfovf
# 10-Oct-23 00:15:08: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:08: This version will eventually be removed.
# 10-Oct-23 00:15:08: Time clip was applied to: ela_pef_fs_LCdeg
# 10-Oct-23 00:15:08: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:08: This version will eventually be removed.
# 10-Oct-23 00:15:08: Time clip was applied to: ela_pef_fs_antiLCdeg
# 10-Oct-23 00:15:08: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:08: This version will eventually be removed.
# 10-Oct-23 00:15:08: Time clip was applied to: ela_pef_fs_epa_spec
# 10-Oct-23 00:15:08: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:08: This version will eventually be removed.
# 10-Oct-23 00:15:08: Time clip was applied to: ela_pef_nspinsinsum
# 10-Oct-23 00:15:08: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:08: This version will eventually be removed.
# 10-Oct-23 00:15:08: Time clip was applied to: ela_pef_nsectors
# 10-Oct-23 00:15:08: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:08: This version will eventually be removed.
# 10-Oct-23 00:15:08: Time clip was applied to: ela_pef_sect2add
# 10-Oct-23 00:15:08: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:08: This version will eventually be removed.
# 10-Oct-23 00:15:08: Time clip was applied to: ela_pef_spinph2add
# 10-Oct-23 00:15:08: ELFIN EPD: LOADING END.
# 10-Oct-23 00:15:08: ELFIN EPD L2: START PROCESSING.
# 10-Oct-23 00:15:08: ELFIN EPD L2: START ENERGY SPECTOGRAM.
# 10-Oct-23 00:15:08: ELFIN EPD L2: START PITCH ANGLE SPECTOGRAM.
# 10-Oct-23 00:15:08: Energy channel [(0, 2), (3, 5), (6, 8), (9, 15)] are used for epd l2 pitch angle spectra.

# %%
# load l2 full spin eflux data
epd_l2_hs_nflux = pyspedas.elfin.epd(
    trange=trange, 
    probe=probe, 
    level='l2', 
    type_='eflux', 
    fullspin=True)
# Out:
# 10-Oct-23 00:15:08: ELFIN EPD: START LOADING.
# 10-Oct-23 00:15:08: Downloading remote index: https://data.elfin.ucla.edu/ela/l2/epd/fast/electron/2021/
# 10-Oct-23 00:15:08: File is current: elfin_data/ela/l2/epd/fast/electron/2021/ela_l2_epdef_20210714_v01.cdf
# 10-Oct-23 00:15:08: Unable to get ydata for variable ela_pef_Tspin
# 10-Oct-23 00:15:09: Conflicting size for at least one dimension for variable ela_pef_hs_epa_spec
# 10-Oct-23 00:15:09: Could not create coordinate v_dim for variable ela_pef_hs_epa_spec
# 10-Oct-23 00:15:09: Conflicting size for at least one dimension for variable ela_pef_fs_epa_spec
# 10-Oct-23 00:15:09: Could not create coordinate v_dim for variable ela_pef_fs_epa_spec
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_Et_nflux
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_Et_eflux
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_Et_dfovf
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_pa
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_spinphase
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_sectnum
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_hs_Epat_nflux
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_hs_Epat_eflux
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_hs_Epat_dfovf
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_hs_LCdeg
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_hs_antiLCdeg
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_hs_epa_spec
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_fs_Epat_nflux
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_fs_Epat_eflux
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_fs_Epat_dfovf
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_fs_LCdeg
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_fs_antiLCdeg
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_fs_epa_spec
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_nspinsinsum
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_nsectors
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_sect2add
# 10-Oct-23 00:15:09: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:09: This version will eventually be removed.
# 10-Oct-23 00:15:09: Time clip was applied to: ela_pef_spinph2add
# 10-Oct-23 00:15:09: ELFIN EPD: LOADING END.
# 10-Oct-23 00:15:09: ELFIN EPD L2: START PROCESSING.
# 10-Oct-23 00:15:09: ELFIN EPD L2: START ENERGY SPECTOGRAM.
# 10-Oct-23 00:15:09: ELFIN EPD L2: START PITCH ANGLE SPECTOGRAM.
# 10-Oct-23 00:15:09: Energy channel [(0, 2), (3, 5), (6, 8), (9, 15)] are used for epd l2 pitch angle spectra.

# %%
# plot energy spectrogram
tplot(['ela_pef_hs_nflux_omni', 'ela_pef_hs_nflux_para', 'ela_pef_hs_nflux_anti','ela_pef_hs_nflux_perp'])

# %%
# plot pitch angle spectrogram
tplot(['ela_pef_hs_nflux_ch0', 'ela_pef_hs_nflux_ch1', 'ela_pef_hs_nflux_ch2', 'ela_pef_hs_nflux_ch3'])

# %% [markdown]
# #### 3.2 add loss cone line to pitch angle spectrogram plot

# %%
options('ela_pef_hs_LCdeg','thick', 3)
options('ela_pef_hs_LCdeg','line_style', 'solid_line')
options('ela_pef_hs_antiLCdeg','thick', 3)
options('ela_pef_hs_antiLCdeg','line_style', 'dash')

# %%
store_data('ela_pef_hs_nflux_ch0_LC', data=['ela_pef_hs_nflux_ch0', 'ela_pef_hs_LCdeg', 'ela_pef_hs_antiLCdeg'])
tplot('ela_pef_hs_nflux_ch0_LC')

# %% [markdown]
# #### 3.3 modify tolerance angle for energy spectrogram

# %% [markdown]
# There are two tolerance angles for energy spectrogram:
# - Espec_LCfatol: tolerance angle for para and anti flux. A positive value makes the loss cone/antiloss cone smaller by specified amount. Default is 22.25 deg.
# - Espec_LCfptol: tolerance angle for perp flux. A negative value means a wider angle for perp flux by specified amount. Default is -11 deg.

# %%
epd_l2_hs_nflux = pyspedas.elfin.epd(
    trange=trange, 
    probe=probe, 
    level='l2', 
    type_='nflux', 
    fullspin=False,
    Espec_LCfatol=15,
    Espec_LCfptol=-20, 
    )
tplot(['ela_pef_hs_nflux_omni', 'ela_pef_hs_nflux_para', 'ela_pef_hs_nflux_anti', 'ela_pef_hs_nflux_perp'])
# Out:
# 10-Oct-23 00:15:12: ELFIN EPD: START LOADING.
# 10-Oct-23 00:15:12: Downloading remote index: https://data.elfin.ucla.edu/ela/l2/epd/fast/electron/2021/
# 10-Oct-23 00:15:13: File is current: elfin_data/ela/l2/epd/fast/electron/2021/ela_l2_epdef_20210714_v01.cdf
# 10-Oct-23 00:15:13: Unable to get ydata for variable ela_pef_Tspin
# 10-Oct-23 00:15:13: Conflicting size for at least one dimension for variable ela_pef_hs_epa_spec
# 10-Oct-23 00:15:13: Could not create coordinate v_dim for variable ela_pef_hs_epa_spec
# 10-Oct-23 00:15:13: Conflicting size for at least one dimension for variable ela_pef_fs_epa_spec
# 10-Oct-23 00:15:13: Could not create coordinate v_dim for variable ela_pef_fs_epa_spec
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_Et_nflux
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_Et_eflux
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_Et_dfovf
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_pa
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_spinphase
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_sectnum
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_hs_Epat_nflux
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_hs_Epat_eflux
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_hs_Epat_dfovf
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_hs_LCdeg
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_hs_antiLCdeg
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_hs_epa_spec
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_fs_Epat_nflux
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_fs_Epat_eflux
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_fs_Epat_dfovf
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_fs_LCdeg
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_fs_antiLCdeg
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_fs_epa_spec
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_nspinsinsum
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_nsectors
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_sect2add
# 10-Oct-23 00:15:13: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:13: This version will eventually be removed.
# 10-Oct-23 00:15:13: Time clip was applied to: ela_pef_spinph2add
# 10-Oct-23 00:15:13: ELFIN EPD: LOADING END.
# 10-Oct-23 00:15:13: ELFIN EPD L2: START PROCESSING.
# 10-Oct-23 00:15:13: ELFIN EPD L2: START ENERGY SPECTOGRAM.
# 10-Oct-23 00:15:14: ELFIN EPD L2: START PITCH ANGLE SPECTOGRAM.
# 10-Oct-23 00:15:14: Energy channel [(0, 2), (3, 5), (6, 8), (9, 15)] are used for epd l2 pitch angle spectra.

# %% [markdown]
# #### 3.4 modify energy channels for pitch angle spectrogram
# Energy channel table:
# | energy_channel  | energy_range (keV) | energy_midbin (keV)|
# |:-----|:------:|-----:|
# | 0   | 50-80     | 63.2     |
# | 1   | 80-120    | 97.9     |
# | 2   | 120-160   | 138.5    |
# | 3   | 160-210   | 183.3    |
# | 4   | 210-270   | 238.1    |
# | 5   | 270-345   | 305.2    |
# | 6   | 345-430   | 385.1    |
# | 7   | 430-630   | 520.4    |
# | 8   | 630-900   | 752.9    |
# | 9   | 900-1300  | 1081.6   |
# | 10  | 1300-1800 | 1529.7   |
# | 11  | 1800-2500 | 2121.3   |
# | 12  | 2500-3350 | 2893.9   |
# | 13  | 3350-4150 | 3728.6   |
# | 14  | 4150-5800 | 4906.1   |
# | 15  | 5800+     | 6500.0   |
#
# There are two ways to set energy channels for pitch angel spectrogram.
#
# Examples of specified energy bins:
# - PAspec_energybins = [(0,2), (3,5), (6,8), (9,15)] (default)
#
# Examples of specified energy channels:
# - PAspec_energies = [(50.,160.), (160.,345.), (345.,900.), (900.,7000.)]
#
#
# If both 'PAspec_energybins' and 'PAspec_energies' are set, 'PAspec_energybins' takes precedence.

# %%
epd_l2_hs_nflux = pyspedas.elfin.epd(
    trange=trange, 
    probe=probe, 
    level='l2', 
    type_='nflux', 
    fullspin=False,
    PAspec_energybins = [(0,3), (4,8)]
    )
print(epd_l2_hs_nflux)
# Out:
# 10-Oct-23 00:15:15: ELFIN EPD: START LOADING.
# 10-Oct-23 00:15:15: Downloading remote index: https://data.elfin.ucla.edu/ela/l2/epd/fast/electron/2021/
# 10-Oct-23 00:15:15: File is current: elfin_data/ela/l2/epd/fast/electron/2021/ela_l2_epdef_20210714_v01.cdf
# 10-Oct-23 00:15:15: Unable to get ydata for variable ela_pef_Tspin
# 10-Oct-23 00:15:16: Conflicting size for at least one dimension for variable ela_pef_hs_epa_spec
# 10-Oct-23 00:15:16: Could not create coordinate v_dim for variable ela_pef_hs_epa_spec
# 10-Oct-23 00:15:16: Conflicting size for at least one dimension for variable ela_pef_fs_epa_spec
# 10-Oct-23 00:15:16: Could not create coordinate v_dim for variable ela_pef_fs_epa_spec
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_Et_nflux
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_Et_eflux
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_Et_dfovf
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_pa
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_spinphase
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_sectnum
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_hs_Epat_nflux
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_hs_Epat_eflux
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_hs_Epat_dfovf
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_hs_LCdeg
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_hs_antiLCdeg
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_hs_epa_spec
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_fs_Epat_nflux
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_fs_Epat_eflux
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_fs_Epat_dfovf
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_fs_LCdeg
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_fs_antiLCdeg
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_fs_epa_spec
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_nspinsinsum
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_nsectors
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_sect2add
# 10-Oct-23 00:15:16: time_clip has been moved to the pytplot.tplot_math module. Please update your imports!
# 10-Oct-23 00:15:16: This version will eventually be removed.
# 10-Oct-23 00:15:16: Time clip was applied to: ela_pef_spinph2add
# 10-Oct-23 00:15:16: ELFIN EPD: LOADING END.
# 10-Oct-23 00:15:16: ELFIN EPD L2: START PROCESSING.
# 10-Oct-23 00:15:16: ELFIN EPD L2: START ENERGY SPECTOGRAM.
# 10-Oct-23 00:15:16: ELFIN EPD L2: START PITCH ANGLE SPECTOGRAM.
# 10-Oct-23 00:15:16: Energy channel [(0, 3), (4, 8)] are used for epd l2 pitch angle spectra.
# ['ela_pef_hs_nflux_omni', 'ela_pef_hs_nflux_para', 'ela_pef_hs_nflux_anti', 'ela_pef_hs_nflux_perp', 'ela_pef_hs_nflux_ch0', 'ela_pef_hs_nflux_ch1']

# %%
tplot(['ela_pef_hs_nflux_ch0', 'ela_pef_hs_nflux_ch1'])
